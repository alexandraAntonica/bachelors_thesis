# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Example feature importance data for XGBoost (gain)
xgb_importance = {
    'SNP_21753': 69.8944,
    'SNP_58112': 63.1727,
    'group_164': 22.5894,
    'SNP_12731': 20.5546,
    'COQ3_2~~~COQ5': 17.4811,
    'SNP_1839': 13.7876,
    'group_2749': 12.9819,
    'group_1514': 10.2233,
    'group_2558': 5.3143,
    'SNP_53989': 5.2803,
    'group_2794': 5.0936,
    'opuD_1~~~betL_1~~~betL': 4.0733,
    'SNP_26734': 3.9493,
    'SNP_56613': 3.9467,
    'SNP_4146': 3.6640,
    'essC_2~~~eccC~~~essC~~~essC_1': 2.7855,
    'group_4019': 2.6516,
    'SNP_21268': 2.5999,
    'SNP_59611': 2.4423,
    'group_3266': 2.1273
}

# Create DataFrame and sort
df = pd.DataFrame.from_dict(xgb_importance, orient='index', columns=['Gain']).sort_values('Gain', ascending=True)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Gain', y=df.index, data=df, palette='coolwarm', hue=df.index)
plt.title('Top 20 Features by Gain (XGBoost - SA Resistance to AMG)', fontsize=14)
plt.xlabel('Gain')
plt.grid(axis='x', linestyle='--', alpha=0.4)  # Clean vertical grid only
plt.tight_layout()
plt.show()

# %%
xgb_importance = {
    'group_3309': 36.7113,
    'group_2437': 16.4217,
    'group_2596': 5.2304,
    'SNP_28950': 4.3880,
    'merA_1~~~merA_2~~~merA_3~~~merA_4~~~merA': 4.0287,
    'SNP_5639': 3.6605,
    'tetS~~~tetM_2~~~tetM_1~~~tetM~~~tetM': 3.6556,
    'SNP_16859': 3.4080,
    'group_3109': 3.3663,
    'SNP_29106': 3.1304,
    'SNP_6909': 2.5694,
    'SNP_23153': 2.4149,
    'SNP_40004': 1.7083,
    'SNP_54228': 1.6667,
    'SNP_13024': 1.6111,
    'SNP_15860': 1.5278,
    'group_3232': 1.3376,
    'SNP_31685': 1.2369,
    'group_4660': 1.0353,
    'SNP_595': 1.0333
}

# Create DataFrame and sort
df = pd.DataFrame.from_dict(xgb_importance, orient='index', columns=['Gain']).sort_values('Gain', ascending=True)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Gain', y=df.index, data=df, palette='coolwarm', hue=df.index)
plt.title('Top 20 Features by Gain (XGBoost - SA Resistance to TET)', fontsize=14)
plt.xlabel('Gain')
plt.grid(axis='x', linestyle='--', alpha=0.4)  # Clean vertical grid only
plt.tight_layout()
plt.show()

# %%
xgb_importance = {
    'SNP_13084': 52.5126,
    'SNP_52232': 18.1868,
    'group_2889': 11.5754,
    'SNP_13075': 5.0248,
    'SNP_30538': 3.8523,
    'lnrL_2~~~drrA~~~cysA~~~lnrL': 1.7646,
    'group_2886': 1.6400,
    'SNP_2847': 1.5114,
    'SNP_38834': 1.4042,
    'SNP_29621': 1.1368,
    'lagD_1~~~irtA~~~lagD_3~~~lagD_2~~~lagD': 0.9471,
    'group_3086': 0.7961,
    'SNP_29443': 0.7826,
    'SNP_663': 0.7030,
    'group_2375': 0.6276,
    'SNP_29903': 0.3681,
    'manX_2': 0.3428,
    'group_2272': 0.2991,
    'group_1904': 0.2693,
    'SNP_20889': 0.2202
}


# Create DataFrame and sort
df = pd.DataFrame.from_dict(xgb_importance, orient='index', columns=['Gain']).sort_values('Gain', ascending=True)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Gain', y=df.index, data=df, palette='coolwarm', hue=df.index)
plt.title('Top 20 Features by Gain (XGBoost - SA Resistance to BAC)', fontsize=14)
plt.xlabel('Gain')
plt.grid(axis='x', linestyle='--', alpha=0.4)  # Clean vertical grid only
plt.tight_layout()
plt.show()

# %%
xgb_importance = {
    'cat': 111.4596,
    'group_3968': 3.7431,
    'SNP_1652': 2.5920,
    'group_1470': 2.5381,
    'SNP_110749': 2.4435,
    'SNP_129614': 2.4167,
    'SNP_14935': 2.2613,
    'SNP_172399': 2.1879,
    'group_2311': 2.1723,
    'SNP_13909': 2.1129,
    'SNP_41623': 2.0372,
    'group_3901': 1.9255,
    'SNP_22823': 1.9214,
    'SNP_40518': 1.8482,
    'SNP_62718': 1.7785,
    'SNP_151828': 1.6885,
    'SNP_94016': 1.6042,
    'SNP_5410': 1.5422,
    'SNP_50875': 1.5033,
    'SNP_99838': 1.4644
}

# Create DataFrame and sort
df = pd.DataFrame.from_dict(xgb_importance, orient='index', columns=['Gain']).sort_values('Gain', ascending=True)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Gain', y=df.index, data=df, palette='coolwarm', hue=df.index)
plt.title('Top 20 Features by Gain (XGBoost - SP Resistance to CHL)', fontsize=14)
plt.xlabel('Gain')
plt.grid(axis='x', linestyle='--', alpha=0.4)  # Clean vertical grid only
plt.tight_layout()
plt.show()

# %%
xgb_importance = {
    'tetM~~~tetM': 51.5613,
    'group_1908': 3.0341,
    'SNP_18127': 2.9268,
    'SNP_20862': 2.8556,
    'SNP_49164': 2.8068,
    'SNP_57304': 2.6557,
    'SNP_79490': 2.6440,
    'SNP_157035': 2.5178,
    'SNP_73928': 2.3471,
    'SNP_62886': 2.3211,
    'SNP_62514': 2.1828,
    'group_2131': 2.1181,
    'SNP_113800': 1.9871,
    'SNP_20869': 1.8898,
    'SNP_37850': 1.8070,
    'group_2240': 1.7177,
    'SNP_157964': 1.6822,
    'SNP_171423': 1.6170,
    'SNP_79614': 1.5537,
    'SNP_95128': 1.5105
}


# Create DataFrame and sort
df = pd.DataFrame.from_dict(xgb_importance, orient='index', columns=['Gain']).sort_values('Gain', ascending=True)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Gain', y=df.index, data=df, palette='coolwarm', hue=df.index)
plt.title('Top 20 Features by Gain (XGBoost - SP Resistance to TET)', fontsize=14)
plt.xlabel('Gain')
plt.grid(axis='x', linestyle='--', alpha=0.4)  # Clean vertical grid only
plt.tight_layout()
plt.show()

# %%
xgb_importance = {
    'group_2302': 120.8449,
    'group_3059': 25.8074,
    'SNP_50163': 23.5318,
    'group_942': 20.7909,
    'SNP_85425': 17.5218,
    'SNP_131644': 12.2937,
    'SNP_110383': 10.9094,
    'SNP_161178': 10.1620,
    'group_2303': 9.4705,
    'SNP_129714': 5.5877,
    'group_2333': 5.2150,
    'group_3612': 4.1739,
    'SNP_10552': 3.9694,
    'SNP_70101': 3.6774,
    'SNP_88232': 3.6476,
    'SNP_18860': 2.7554,
    'SNP_20426': 2.2791,
    'group_3306': 2.1667,
    'SNP_85749': 2.0668,
    'nanA_1~~~nanA_2~~~nanA_3': 1.9626
}


# Create DataFrame and sort
df = pd.DataFrame.from_dict(xgb_importance, orient='index', columns=['Gain']).sort_values('Gain', ascending=True)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Gain', y=df.index, data=df, palette='coolwarm', hue=df.index)
plt.title('Top 20 Features by Gain (XGBoost - SP Resistance to AZM)', fontsize=14)
plt.xlabel('Gain')
plt.grid(axis='x', linestyle='--', alpha=0.4)  # Clean vertical grid only
plt.tight_layout()
plt.show()

# %%
xgb_importance = {
    'xerC_7~~~xerC_2~~~xerC_9~~~xerC_5~~~xerC_6~~~xerD_2~~~xerD_4~~~xerC_4~~~xerC_3~~~xerC_10~~~xerC_8': 49.6737,
    'SNP_30497': 7.5976,
    'SNP_10945': 7.3405,
    'yokD': 7.2994,
    'ant1~~~ant1_1~~~ant1_2': 5.5954,
    'SNP_211839': 4.6809,
    'SNP_386188': 4.1946,
    'dhfrI_2~~~dhfrI': 3.8119,
    'group_7843': 3.7079,
    'group_5068': 3.6704,
    'SNP_70408': 3.5626,
    'SNP_374858': 3.4492,
    'SNP_255316': 3.1931,
    'rfbA~~~rmlA~~~rfbA_1': 2.9234,
    'group_14444': 2.8680,
    'SNP_498177': 2.6865,
    'SNP_313405': 2.5440,
    'ermD': 2.5281,
    'SNP_113260': 2.3921,
    'folP_2~~~folP_3~~~sulA_2~~~folP_5': 2.3255
}


# Create DataFrame and sort
df = pd.DataFrame.from_dict(xgb_importance, orient='index', columns=['Gain']).sort_values('Gain', ascending=True)

# Plot
plt.figure(figsize=(20, 6))
sns.barplot(x='Gain', y=df.index, data=df, palette='coolwarm', hue=df.index)
plt.title('Top 20 Features by Gain (XGBoost - Ecoli Resistance to TMP)', fontsize=14)
plt.xlabel('Gain')
plt.grid(axis='x', linestyle='--', alpha=0.4)  # Clean vertical grid only
plt.tight_layout()
plt.show()

# %%
xgb_importance = {
    'xerC_7~~~xerC_2~~~xerC_9~~~xerC_5~~~xerC_6~~~xerD_2~~~xerD_4~~~xerC_4~~~xerC_3~~~xerC_10~~~xerC_8': 70.5672,
    'folP_2~~~folP_3~~~sulA_2~~~folP_5': 13.6678,
    'SNP_220459': 6.7422,
    'ant1~~~ant1_1~~~ant1_2': 6.0193,
    'group_14282': 5.4868,
    'group_13942': 5.2925,
    'group_4216': 5.0465,
    'group_14713': 4.9573,
    'SNP_484835': 4.7708,
    'SNP_484691': 4.7247,
    'group_1603': 4.2106,
    'SNP_143134': 4.1685,
    'group_14373': 4.0888,
    'SNP_86693': 4.0777,
    'emrE~~~mdtI_2~~~qacC~~~mmr~~~folP1~~~mdtJ_1': 3.9918,
    'SNP_218917': 3.9713,
    'SNP_286741': 3.7645,
    'SNP_62344': 3.2561,
    'group_13782': 3.1900,
    'SNP_234254': 2.8858
}


# Create DataFrame and sort
df = pd.DataFrame.from_dict(xgb_importance, orient='index', columns=['Gain']).sort_values('Gain', ascending=True)

# Plot
plt.figure(figsize=(20, 6))
sns.barplot(x='Gain', y=df.index, data=df, palette='coolwarm', hue=df.index)
plt.title('Top 20 Features by Gain (XGBoost - Ecoli Resistance to SUL)', fontsize=14)
plt.xlabel('Gain')
plt.grid(axis='x', linestyle='--', alpha=0.4)  # Clean vertical grid only
plt.tight_layout()
plt.show()

# %%
xgb_importance = {
    'SNP_351032': 186.6480,
    'SNP_460759': 71.9816,
    'SNP_18342': 65.0801,
    'SNP_156222': 28.7044,
    'SNP_108136': 23.3501,
    'group_19469': 15.9250,
    'SNP_460803': 14.6801,
    'group_6960': 14.6251,
    'SNP_403722': 8.7476,
    'SNP_249398': 8.2388,
    'SNP_34669': 8.0820,
    'noc~~~spo0C~~~noc_1~~~noc_3~~~noc_2': 7.8000,
    'SNP_120787': 7.1530,
    'SNP_442759': 7.0767,
    'SNP_66247': 6.9823,
    'SNP_11795': 4.8157,
    'SNP_406741': 4.1300,
    'group_12770': 3.7462,
    'group_13747': 3.6000,
    'bla_3~~~bla_4~~~bla~~~bla_2~~~bla_1': 2.8455
}


# Create DataFrame and sort
df = pd.DataFrame.from_dict(xgb_importance, orient='index', columns=['Gain']).sort_values('Gain', ascending=True)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Gain', y=df.index, data=df, palette='coolwarm', hue=df.index)
plt.title('Top 20 Features by Gain (XGBoost - Ecoli Resistance to CTX)', fontsize=14)
plt.xlabel('Gain')
plt.grid(axis='x', linestyle='--', alpha=0.4)  # Clean vertical grid only
plt.tight_layout()
plt.show()
